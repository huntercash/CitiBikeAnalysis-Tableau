# %%
import pandas as pd
import os

# %%
nov2018csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201811-citibike-tripdata.csv'))
dec2018csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201812-citibike-tripdata.csv'))
jan2019csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201901-citibike-tripdata.csv'))
feb2019csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201902-citibike-tripdata.csv'))
mar2019csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201903-citibike-tripdata.csv'))
apr2019csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201904-citibike-tripdata.csv'))
may2019csv = pd.read_csv(os.path.join('CitiBikeData', 'JC-201905-citibike-tripdata.csv'))

# %%
frames = [nov2018csv, dec2018csv, jan2019csv, feb2019csv, mar2019csv, apr2019csv, may2019csv]

# %%
df = pd.concat(frames)

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1           278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2           115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3           155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4            82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
df.nunique()
# Out:
# tripduration                 4529
# starttime                  176150
# stoptime                   176150
# start station id               52
# start station name             52
# start station latitude         53
# start station longitude        53
# end station id                 77
# end station name               77
# end station latitude           78
# end station longitude          78
# bikeid                        595
# usertype                        2
# birth year                     67
# gender                          3
# dtype: int64

# %%
df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.761530e+05     176153.000000           176153.000000
# mean   6.363645e+02       3274.702418               40.722848
# std    7.256507e+03        147.776851                0.007125
# min    6.100000e+01       3183.000000               40.709651
# 25%    2.180000e+02       3192.000000               40.718355
# 50%    3.170000e+02       3207.000000               40.721525
# 75%    5.090000e+02       3273.000000               40.727224
# max    1.729020e+06       3791.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count            176153.000000   176153.000000         176153.000000
# mean                -74.046585     3269.396417             40.722411
# std                   0.010792      151.511971              0.006936
# min                 -74.083639      195.000000             40.703006
# ...

# %%
df.reset_index()
# Out:
#         index  tripduration                 starttime  \
# 0           0          1188  2018-11-01 06:32:27.5190
# 1           1           278  2018-11-01 07:14:31.8680
# 2           2           115  2018-11-01 07:33:17.1920
# 3           3           155  2018-11-01 08:20:10.9320
# 4           4            82  2018-11-01 08:35:02.7850
# 5           5           310  2018-11-01 08:53:23.7250
# 6           6           203  2018-11-01 08:54:47.4150
# 7           7           176  2018-11-01 09:04:07.4190
# 8           8           269  2018-11-01 09:52:26.7690
# 9           9          1010  2018-11-01 11:11:43.7110
# 10         10          1001  2018-11-01 11:11:51.8740
# 11         11           986  2018-11-01 11:12:04.6990
# 12         12           277  2018-11-01 12:02:26.3600
# 13         13           226  2018-11-01 12:10:09.6930
# 14         14          1102  2018-11-01 12:44:52.0440
# 15         15           517  2018-11-01 13:15:02.0680
# ...

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1188  2018-11-01 06:32:27.5190  2018-11-01 06:52:15.9140
# 1           278  2018-11-01 07:14:31.8680  2018-11-01 07:19:10.2610
# 2           115  2018-11-01 07:33:17.1920  2018-11-01 07:35:12.2830
# 3           155  2018-11-01 08:20:10.9320  2018-11-01 08:22:46.7050
# 4            82  2018-11-01 08:35:02.7850  2018-11-01 08:36:25.1840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
df.to_csv(os.path.join('CitiBikeData', 'q4-2018_q12019.csv'))
